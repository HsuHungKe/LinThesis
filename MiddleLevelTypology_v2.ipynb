# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# store dataset to python
# note: put the intended dataname within "". If it is within the same file just the name. Otherwise inventory
df = pd.read_csv("thesis data.csv", encoding ='utf-8')

# %%
#Choosing only datas of metonymy
df_new=df[df['strategy']=='Metonymy']
# df_new
# Separating target lines & rename
# reference(Line 6): https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html

# %%
#df_new.head()
# Out:
#    Subject concept  figure      frame  strategy coding Type description
# 0      3.0      美味     1.0  sensation  Metonymy    吃豬腳   食物     process
# 1      3.0      美味     2.0  sensation  Metonymy    冰淇淋   食物      object
# 2     10.0      美味     1.0  sensation  Metonymy     美食   食物   situation
# 3     14.0      美味     1.0  sensation  Metonymy     牛排   食物      object
# 4     14.0      美味     2.0  sensation  Metonymy     魚排   食物      object

# %%
df_stone=df_new[df_new['concept']=='石頭']
df_poem=df_new[df_new['concept']=='詩意']
df_test=df_new[(df_new['concept']=='石頭')|(df_new['concept']=='詩意')]

# %%
df_test=df_test. groupby(['concept','Type']).Type.agg([len]).sort_values(by=['concept','len'], ascending=False)
df_test
# Out:
#                len
# concept Type
# 詩意      文本      24
#         場景       8
#         動作       7
#         工具       4
#         上課       3
#         季節、天氣    2
#         意思       1
#         愛情       1
#         植物       1
#         靈感       1
#         飲食       1
# 石頭      地點      30
#         樣貌、特性   25
#         工具      11
#         事件       6
#         功能       3
#         堆疊       3
#         動作       2
#         卡通       2
#         其他       1
#         寶石       1

# %%
df_test=df_test.reset_index()

# %%
df_test
# Out:
#    concept   Type  len
# 0       詩意     文本   24
# 1       詩意     場景    8
# 2       詩意     動作    7
# 3       詩意     工具    4
# 4       詩意     上課    3
# 5       詩意  季節、天氣    2
# 6       詩意     意思    1
# 7       詩意     愛情    1
# 8       詩意     植物    1
# 9       詩意     靈感    1
# 10      詩意     飲食    1
# 11      石頭     地點   30
# 12      石頭  樣貌、特性   25
# 13      石頭     工具   11
# 14      石頭     事件    6
# 15      石頭     功能    3
# 16      石頭     堆疊    3
# 17      石頭     動作    2
# 18      石頭     卡通    2
# 19      石頭     其他    1
# 20      石頭     寶石    1

# %%
# Here are the codes to use display Chinese on Python
from matplotlib.font_manager import FontProperties

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.rcParams['axes.unicode_minus'] = False

# %%
type(df_test.reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
list_test = ['石頭','詩意']
fig = plt.figure(figsize=(15,6))
  
for i in range(len(list_test)):

    # Take out only one word
    df_agg = df_test[df_test['concept']==list_test[i]] # take only one
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
    fig.add_subplot(1, 2, i+1) #separate canvas
    

    #***https://matplotlib.org/stable/gallery/misc/table_demo.html#sphx-glr-gallery-misc-table-demo-py 複雜版
    #https://matplotlib.org/stable/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py 簡易
    #pv_pic.plot.bar(x='類型',y='數量') 不是用於matplotlib
    plt.bar(df_agg['Type'],df_agg['len'],color="dimgrey")
    plt.xticks(rotation=-50) #x軸斜體
    plt.title(list_test[i])

    # bar graph 參數 1. https://iter01.com/569325.html 2. https://steam.oxxostudio.tw/category/python/example/matplotlib-bar.html
fig.tight_layout() # Creating suitable spacing
fig.savefig('category_test.jpg') # export data seperately as jpg; https://www.youtube.com/watch?v=qpVhubsBcdk 
    
#spacing between figures; refer to https://www.geeksforgeeks.org/how-to-set-the-spacing-between-subplots-in-matplotlib-in-python/

plt.show()
